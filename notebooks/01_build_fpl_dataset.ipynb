# %% [markdown]
# # FPL Dataset Builder
#
# This notebook creates the first dataset for **Fantasy Premier League Points Prediction** project.
#
# It gathers:
# - Historical FPL gameweek data (2016-17 to 2024-25)
# - Live player pool from the official FPL API
# - Optional Understat xG/xA enrichment (best-effort)
#
# Outputs:
# - `data/processed/fpl_model_dataset.csv`
# - `data/processed/live_player_pool.csv`

# %%
from pathlib import Path
import sys

cwd = Path.cwd().resolve()
PROJECT_ROOT = cwd.parent if cwd.name == "notebooks" else cwd

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

PROJECT_ROOT

# %%
from scripts.build_dataset import build_dataset

result = build_dataset(root=PROJECT_ROOT)
historical_df = result["historical_dataset"]
live_df = result["live_player_pool"]

historical_df.shape, live_df.shape

# %%
historical_df.head()

# %%
feature_cols = [
    c for c in historical_df.columns
    if c.endswith("_roll3") or c.endswith("_roll5") or c in [
        "rest_days",
        "was_home",
        "opponent_team",
        "value",
        "selected",
        "transfers_in",
        "transfers_out",
        "position",
    ]
]

print("Approx feature count:", len(feature_cols))
feature_cols[:20]
